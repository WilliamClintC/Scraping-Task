# %%
import os
import re

# Directory containing the PDF files
pdf_directory = r"C:\Users\clint\Desktop\Scraping Task\pdfs"

# Helper function to convert month name to number
def month_to_number(month_name):
    months = {
        "january": "01", "february": "02", "march": "03", "april": "04",
        "may": "05", "june": "06", "july": "07", "august": "08",
        "september": "09", "october": "10", "november": "11", "december": "12"
    }
    return months.get(month_name.lower(), "00")

# Get all files in the directory
files = os.listdir(pdf_directory)

for filename in files:
    if filename.lower().endswith('.pdf'):
        full_path = os.path.join(pdf_directory, filename)
        new_filename = None
        
        # Try to match decimal format like "04.2019_Commercial Truck Guidelines_1.pdf"
        match = re.match(r"(\d+)\.(\d{4})_.*\.pdf", filename)
        if match:
            month, year = match.groups()
            new_filename = f"{month}_{year}.pdf"
        
        # Try to match month name format like "August_2022_Guidelines.pdf"
        if not new_filename:
            match = re.match(r"([A-Za-z]+)_(\d{4})_.*\.pdf", filename)
            if match:
                month_name, year = match.groups()
                month_num = month_to_number(month_name)
                new_filename = f"{month_num}_{year}.pdf"
        
        # If a new filename was generated
        if new_filename:
            new_full_path = os.path.join(pdf_directory, new_filename)
            
            # Check if destination file already exists
            if os.path.exists(new_full_path) and full_path != new_full_path:
                print(f"Skipping {filename} - target file {new_filename} already exists")
                continue
                
            # Rename the file
            try:
                os.rename(full_path, new_full_path)
                print(f"Renamed: {filename} -> {new_filename}")
            except Exception as e:
                print(f"Error renaming {filename}: {e}")
        else:
            print(f"Skipping {filename} - doesn't match any expected pattern")

print("Renaming completed.")
# Out:
# Renamed: 01.2018_Commercial%20Truck_Guidelines.pdf -> 01_2018.pdf
# Skipping 01.2018_Commercial%20Truck_Guidelines_1.pdf - target file 01_2018.pdf already exists
# Renamed: 01.2019_Commercial%20Truck_Guidelines.pdf -> 01_2019.pdf
# Renamed: 01.2020_Commercial%20Truck%20Guidelines.pdf -> 01_2020.pdf
# Renamed: 01.2021_Commercial Truck Guidelines.pdf -> 01_2021.pdf
# Skipping 01.2021_Commercial%20Truck%20Guidelines.pdf - target file 01_2021.pdf already exists
# Renamed: 01.2022_Commercial%20Truck%20Guidelines.pdf -> 01_2022.pdf
# Renamed: 01.2023_CommercialVehicleGuidelines_FINAL.pdf -> 01_2023.pdf
# Renamed: 01.2025_CommercialVehicleGuidelines_Final.pdf -> 01_2025.pdf
# Renamed: 02.2018_Commercial%20Truck_Guidelines.pdf -> 02_2018.pdf
# Renamed: 02.2019_Commercial%20Truck%20Guidelines.pdf -> 02_2019.pdf
# Renamed: 02.2020_Commercial%20Truck%20Guidelines.pdf -> 02_2020.pdf
# Renamed: 02.2021_Commercial Truck Guidelines.pdf -> 02_2021.pdf
# Skipping 02.2021_Commercial%20Truck%20Guidelines.pdf - target file 02_2021.pdf already exists
# Renamed: 02.2022_CommercialVehicleGuidelines_FINAL.pdf -> 02_2022.pdf
# Renamed: 02.2023_CommercialVehicleGuidelines_Final.pdf -> 02_2023.pdf
# Renamed: 03.2018_Commercial%20Truck_Guidelines.pdf -> 03_2018.pdf
# Renamed: 03.2019_Commercial%20Truck%20Guidelines_CV.pdf -> 03_2019.pdf
# Renamed: 03.2020_Commercial%20Truck%20Guidelines.pdf -> 03_2020.pdf
# Skipping 03.2020_Commercial%20Truck%20Guidelines_1.pdf - target file 03_2020.pdf already exists
# Renamed: 03.2021_Commercial Truck Guidelines.pdf -> 03_2021.pdf
# Skipping 03.2021_Commercial%20Truck%20Guidelines.pdf - target file 03_2021.pdf already exists
# Renamed: 03.2022_CommercialVehicleGuidelines_FINAL.pdf -> 03_2022.pdf
# Renamed: 03.2023_CommercialVehicleGuidelines.pdf -> 03_2023.pdf
# Renamed: 03.2025_CommercialVehicleGuidelines_Final.pdf -> 03_2025.pdf
# Renamed: 04.2018_Commercial%20Truck_Guidelines.pdf -> 04_2018.pdf
# Renamed: 04.2019_Commercial%20Truck%20Guidelines.pdf -> 04_2019.pdf
# Skipping 04.2019_Commercial%20Truck%20Guidelines_1.pdf - target file 04_2019.pdf already exists
# Renamed: 04.2020_Commercial%20Truck%20Guidelines.pdf -> 04_2020.pdf
# Renamed: 04.2021_Commercial Truck Guidelines.pdf -> 04_2021.pdf
# Skipping 04.2021_Commercial%20Truck%20Guidelines.pdf - target file 04_2021.pdf already exists
# Renamed: 04.2022_CommercialVehicleGuidelines.pdf -> 04_2022.pdf
# Renamed: 04.2023_CommercialVehicleGuidelines_FINAL.pdf -> 04_2023.pdf
# Renamed: 05.2018_Commercial%20Truck_Guidelines.pdf -> 05_2018.pdf
# Renamed: 05.2019_Commercial%20Truck%20Guidelines.pdf -> 05_2019.pdf
# Renamed: 05.2020_Commercial%20Truck%20Guidelines.pdf -> 05_2020.pdf
# Renamed: 05.2021_Commercial Truck Guidelines.pdf -> 05_2021.pdf
# Skipping 05.2021_Commercial%20Truck%20Guidelines.pdf - target file 05_2021.pdf already exists
# Renamed: 05.2022_CommercialVehicleGuidelines_FINAL.pdf -> 05_2022.pdf
# Renamed: 06.2018_Commercial%20Truck_Guidelines.pdf -> 06_2018.pdf
# Renamed: 06.2019_Commercial%20Truck%20GuidelinesPDF.pdf -> 06_2019.pdf
# Renamed: 06.2020_Commercial%20Truck%20Guidelines.pdf -> 06_2020.pdf
# Renamed: 06.2021_Commercial%20Truck%20Guidelines.pdf -> 06_2021.pdf
# Renamed: 06.2023_CommercialVehicleGuidelines_Final.pdf -> 06_2023.pdf
# Renamed: 07.2018_Commercial%20Truck_Guidelines.pdf -> 07_2018.pdf
# Renamed: 07.2019_Commercial%20Truck%20GuidelinesPDF.pdf -> 07_2019.pdf
# Renamed: 07.2020_Commercial%20Truck%20Guidelines.pdf -> 07_2020.pdf
# Renamed: 07.2021_Commercial Truck Guidelines.pdf -> 07_2021.pdf
# Skipping 07.2021_Commercial%20Truck%20Guidelines.pdf - target file 07_2021.pdf already exists
# Renamed: 07.2022_CommercialVehicleGuidelines_Final.pdf -> 07_2022.pdf
# Renamed: 07.2023_CommercialVehicleGuidelines_Final.pdf -> 07_2023.pdf
# Renamed: 08.2018_Commercial%20Truck_Guidelines.pdf -> 08_2018.pdf
# Renamed: 08.2019_Commercial%20Truck%20Guidelines.pdf -> 08_2019.pdf
# Renamed: 08.2020_Commercial%20Truck%20Guidelines.pdf -> 08_2020.pdf
# Renamed: 08.2021_Commercial Truck Guidelines.pdf -> 08_2021.pdf
# Skipping 08.2021_Commercial%20Truck%20Guidelines.pdf - target file 08_2021.pdf already exists
# Renamed: 08.2022_CommercialVehicleGuidelines.pdf -> 08_2022.pdf
# Renamed: 08.2023_CommercialVehicleGuidelines_Final.pdf -> 08_2023.pdf
# Renamed: 09.2018_Commercial%20Truck_Guidelines.pdf -> 09_2018.pdf
# Renamed: 09.2019_Commercial%20Truck%20Guidelines.pdf -> 09_2019.pdf
# Renamed: 09.2020_Commercial%20Truck%20Guidelines.pdf -> 09_2020.pdf
# Renamed: 09.2021_Commercial Truck Guidelines.pdf -> 09_2021.pdf
# Skipping 09.2021_Commercial%20Truck%20Guidelines.pdf - target file 09_2021.pdf already exists
# Renamed: 09.2022_CommercialVehicleGuidelines.pdf -> 09_2022.pdf
# Renamed: 1.2024_CommercialVehicleGuidelines_Final.pdf -> 1_2024.pdf
# Renamed: 10.2018_Used%20Car%20and%20Light%20Truck_Guidelines.pdf -> 10_2018.pdf
# Renamed: 10.2019_Commercial%20Truck%20Guidelines.pdf -> 10_2019.pdf
# Renamed: 10.2020_Commercial%20Truck%20Guidelines.pdf -> 10_2020.pdf
# Renamed: 10.2021_Commercial Truck Guidelines.pdf -> 10_2021.pdf
# Skipping 10.2021_Commercial%20Truck%20Guidelines.pdf - target file 10_2021.pdf already exists
# Renamed: 10.2022_CommercialVehicleGuidelines_Final.pdf -> 10_2022.pdf
# Renamed: 10.2023_CommercialVehicleGuidelines_Final.pdf -> 10_2023.pdf
# Renamed: 11.2018_Commercial%20Truck_Guidelines.pdf -> 11_2018.pdf
# Renamed: 11.2019_Commercial%20Truck%20Guidelines.pdf -> 11_2019.pdf
# Renamed: 11.2020_Commercial%20Truck%20Guidelines.pdf -> 11_2020.pdf
# Renamed: 11.2021_Commercial Truck Guidelines.pdf -> 11_2021.pdf
# Skipping 11.2021_Commercial%20Truck%20Guidelines.pdf - target file 11_2021.pdf already exists
# Renamed: 11.2022_CommercialVehicleGuidelines_FINAL.pdf -> 11_2022.pdf
# Renamed: 12.2018_Commercial%20Truck_Guidelines.pdf -> 12_2018.pdf
# Renamed: 12.2019_Commercial%20Truck%20Guidelines.pdf -> 12_2019.pdf
# Renamed: 12.2021_Commercial%20Truck%20Guidelines.pdf -> 12_2021.pdf
# Renamed: 12.2022_CommercialVehicleGuidelines_GE.pdf -> 12_2022.pdf
# Renamed: 12.2023_CommercialVehicleGuidelines_Final.pdf -> 12_2023.pdf
# Renamed: 2.2024_CommercialVehicleGuidelines_Final.pdf -> 2_2024.pdf
# Renamed: 3.2024_CommercialVehicleGuidelines.pdf -> 3_2024.pdf
# Renamed: 4.2024_CTG.pdf -> 4_2024.pdf
# Renamed: 5.2024_CommercialVehicleGuidelines.pdf -> 5_2024.pdf
# Renamed: 6.2024_CommercialVehicleGuidelines_Final.pdf -> 6_2024.pdf
# Renamed: 7.2024_CommercialVehicleGuidelines.pdf -> 7_2024.pdf
# Renamed: 8.2024_CommercialVehicleGuidelines_Final%5B58%5D.pdf -> 8_2024.pdf
# Renamed: 9.2024_CommercialVehicleGuidelines_Final.pdf -> 9_2024.pdf
# Skipping August_2022_Guidelines.pdf - target file 08_2022.pdf already exists
# Renamed: May_2023_CTG.pdf -> 05_2023.pdf
# Renaming completed.
